# %%
import numpy as np
import pandas as pd
import pickle
import yaml
pd.set_option("display.max_columns", None) # 表示する列数の制限を解除

import sys
sys.path.append("..") # 親ディレクトリを追加
from module.path_reader import PathReader

reader = PathReader("../file_path_NotePC.json") # NotePC用
# reader = PathReader("../file_path_Desktop.json") # Desktop用

# %% [markdown]
# ## テーブルの読み出し

# %%
# what: race_result_table.pklを読み込む
with open(reader.get_path("race_result_table"), "rb") as f:
    df_race = pickle.load(f)

print(df_race.columns)
print(f"Number of items: {len(df_race.columns)}")
df_race
# Out:
# Index(['date', 'race_id', 'is_win', 'rank', 'horse_id', 'weight_carried',
#        'jockey_id', 'popularity', 'odds', 'last3f', 'trainer_id',
#        'body_weight', 'sex', 'age', 'time_sec', 'body_diff'],
#       dtype='object')
# Number of items: 16
#            date       race_id  is_win rank    horse_id  weight_carried  \
# 0      20231001  202309040910       1    1  2019105746            58.0
# 1      20231001  202309040910       0    2  2019102983            58.0
# 2      20231001  202309040910       0    3  2018104746            58.0
# 3      20231001  202309040910       0    4  2019100108            58.0
# 4      20231001  202309040910       0    5  2019103518            58.0
# ...         ...           ...     ...  ...         ...             ...
# 28501  20240428  202408030411       0   14  2018104609            58.0
# 28502  20240428  202408030411       0   15  2020103650            58.0
# 28503  20240428  202408030411       0   16  2016104946            58.0
# 28504  20240428  202408030411       0   中止  2019100630            58.0
# 28505  20240428  202408030411       0   取消  2016104851            58.0
#
#       jockey_id  popularity   odds  last3f trainer_id  body_weight  sex  age  \
# 0         05203         5.0    7.2    35.9      01127        494.0    0  4.0
# 1         01093         8.0   22.2    36.3      01069        494.0    0  4.0
# 2         01174         4.0    7.0    36.8      00429        494.0    2  5.0
# 3         01157        11.0   33.9    37.1      01039        494.0    0  4.0
# 4         01128        10.0   30.1    36.8      00425        532.0    0  4.0
# ...         ...         ...    ...     ...        ...          ...  ...  ...
# 28501     01157         8.0   39.8    39.4      01070        482.0    2  6.0
# 28502     05386         2.0    2.8    40.5      01103        464.0    0  4.0
# 28503     05212         7.0   34.6    40.3      01071        462.0    0  8.0
# 28504     01115        15.0  199.1     NaN      01058        486.0    0  5.0
# 28505     01180         NaN    NaN     NaN      01151          NaN    2  8.0
#
#        time_sec  body_diff
# 0         111.3       -4.0
# 1         111.4       -6.0
# 2         111.5        0.0
# 3         111.6        0.0
# 4         111.6        8.0
# ...         ...        ...
# 28501     199.0       -4.0
# 28502     199.8       -8.0
# 28503     200.0        8.0
# 28504       NaN        2.0
# 28505       NaN        NaN
#
# [28506 rows x 16 columns]

# %%
with open("C:\\Users\\yasak\\デスクトップ\\Keiba_App\\mykeibaAI_ver1p0\\data\\horse_result_table_2404.pkl", "rb") as f:
    # C:\\Users\\yasak\\デスクトップ\\Keiba_App\\mykeibaAI_ver1p0\\data\\horse_result_table_2404.pkl # NotePC
    # C:\\Users\\yasak\\Desktop\\mykeibaAI\\data\\horse_result_table_2404.pkl # Desktop
    df_horse = pickle.load(f)

print(df_horse.columns)
print(f"Number of items: {len(df_horse.columns)}")
df_horse
# Out:
# Index(['horse_id', 'race_date', 'weather', 'race_no', 'race_id',
#        'num_of_horses', 'frame_no', 'horse_no', 'odds', 'popularity',
#        'finish_position', 'jockey_id', 'weight', 'course_condition', 'time',
#        'margin', 'final_3f', 'prize_money', 'course_state', 'distance_length',
#        'passing_1st', 'passing_2nd', 'passing_3rd', 'passing_4th', 'pace_1st',
#        'pace_2nd', 'body_weight', 'body_diff'],
#       dtype='object')
# Number of items: 28
#           horse_id  race_date  weather race_no       race_id num_of_horses  \
# 0       2018104746 2024-03-23      2.0      11  202407010511            16
# 1       2018104746 2024-01-14      0.0      10  202408010510            13
# 2       2018104746 2023-12-23      0.0      10  202309050710            16
# 3       2018104746 2023-10-28      0.0      10  202308020810            15
# 4       2018104746 2023-10-01      1.0      10  202309040910            12
# ...            ...        ...      ...     ...           ...           ...
# 178960  2018100141 2020-07-29      0.0       5  202030072905             7
# 178961  2018100141 2020-07-01      1.0       9  202030070109             9
# 178962  2018100141 2020-06-18      0.0       5  202030061805            12
# 178963  2018100141 2020-06-04      0.0       2  202030060402            11
# 178964  2018100141 2020-05-05      0.0       5  202030050505            10
#
#        frame_no horse_no  odds popularity finish_position jockey_id weight  \
# 0             4        8   9.8          5               4     01095     56
# 1             8       12  85.3          8               6     01199     58
# 2             7       14  13.2          4              10     01174     56
# 3             7       14   3.0          1               9     01088     58
# 4             8       12   7.0          4               3     01174     58
# ...         ...      ...   ...        ...             ...       ...    ...
# 178960        6        6   2.1          1               1     05371     54
# 178961        8        9   3.3          2               2     05371     54
# 178962        6        8  14.4          4               2     05371     54
# 178963        6        6   4.4          2               3     05371     54
# 178964        5        5  83.3         10               5     05371     54
#
#         course_condition   time  margin final_3f prize_money  course_state  \
# 0                    2.0  116.5     0.9     36.5       280.0             1
# 1                    0.0  112.7     0.9     35.9                         1
# 2                    0.0  113.4     1.2     37.8                         1
# 3                    0.0  112.7     1.1     38.6                         1
# 4                    2.0  111.5     0.2     36.8       463.6             1
# ...                  ...    ...     ...      ...         ...           ...
# 178960               0.0  112.9    -0.6     41.3       100.0             1
# 178961               2.0  112.0     1.6     39.7        20.0             1
# 178962               NaN  114.2     0.3     40.3        20.0             1
# 178963               0.0  117.1     2.5     41.7        15.0             1
# 178964               2.0   69.1     1.9     38.0        12.5             1
#
#         distance_length  passing_1st  passing_2nd  passing_3rd  passing_4th  \
# 0                  1900         11.0         11.0         11.0         10.0
# 1                  1800         10.0         11.0         12.0         10.0
# 2                  1800         12.0         13.0         11.0         10.0
# 3                  1800          6.0          5.0          6.0          3.0
# 4                  1800          9.0          9.0          7.0          7.0
# ...                 ...          ...          ...          ...          ...
# 178960             1700          7.0          7.0          5.0          1.0
# 178961             1700          9.0          9.0          9.0          8.0
# 178962             1700         11.0         11.0          9.0          5.0
# 178963             1700          9.0          8.0         10.0          9.0
# 178964             1100         10.0          9.0          NaN          NaN
#
#         pace_1st  pace_2nd  body_weight  body_diff
# 0           29.1      36.4        490.0       -4.0
# 1           37.1      36.1        494.0        0.0
# 2           36.9      37.9        494.0       -2.0
# 3           36.0      38.0        496.0        2.0
# 4           36.4      37.3        494.0        0.0
# ...          ...       ...          ...        ...
# 178960       NaN       NaN        444.0        0.0
# 178961       NaN       NaN        444.0       -6.0
# 178962       NaN       NaN        450.0        0.0
# 178963       NaN       NaN        450.0       10.0
# 178964       NaN       NaN        440.0        0.0
#
# [97485 rows x 28 columns]

# %% [markdown]
# ## 前処理0. horse_result_tableの整形

# %%
# idのカラムをすべて文字列型に変換し、前後の空白を削除する
df_race["race_id"] = df_race["race_id"].astype(str).str.strip()
df_race["horse_id"] = df_race["horse_id"].astype(str).str.strip()
df_horse["race_id"] = df_horse["race_id"].astype(str).str.strip()
df_horse["horse_id"] = df_horse["horse_id"].astype(str).str.strip()

# jockey_idとtrainer_idも同様に処理する
# スクレイピングをしてtableを作成する際にこの処理はやっておく

# %%
# what: horse_result_tableの前処理
# for:  horse_result_tableをrace_result_tableに1対1でマージできるように
# how:  horse_result_tableのrace_idを期間で絞り込み、出走頭数と一致するデータのみを残す。さらに地方競馬場のデータを除外

# 直近nレースから集約できるように並び替えておく
df_horse = df_horse.sort_values(by=["horse_id", "race_date"], ascending=[True, True])
# race_idをスクレイピングした期間のデータに絞る
df_horse_indate = df_horse[(df_horse["race_date"] >= "2023-10-01") & (df_horse["race_date"] <= "2024-04-30")].copy()

# 1. "取"(取消), "除"(除外), ""(空欄)になっている行を出走頭数(actual_horses)のカウントから除外する
df_horse_indate.loc[:, "is_cash"] = df_horse_indate["finish_position"].astype(str).str.strip().isin(["取", "除", ""])
actual_counts = df_horse_indate[~df_horse_indate["is_cash"]].groupby("race_id").size().rename("actual_horses")

# 2. num_of_horses と結合
df_check = df_horse_indate.merge(actual_counts, on="race_id")
# 2.5 num_of_horses を数値型に変換
df_check.loc[:, "num_of_horses"] = pd.to_numeric(df_check["num_of_horses"], errors="coerce")

# 3. 一致しているデータだけ残す
df_clean = df_check[df_check["actual_horses"] == df_check["num_of_horses"]].copy()

# 4. 地方競馬場のデータを除外する
# race_idの5-6桁目を抽出（1-basedで5-6桁 → 0-based slice [4:6]）
df_clean.loc[:, 'race_course_code'] = df_clean['race_id'].str[4:6]
jra_codes = ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10"]  # JRAの中央競馬場コード
df_clean = df_clean[df_clean['race_course_code'].isin(jra_codes)]

# num_of_horsesとrace_course_codeを数値型に変換
df_clean["num_of_horses"] = pd.to_numeric(df_clean["num_of_horses"], errors="coerce")
df_clean["race_course_code"] = pd.to_numeric(df_clean["race_course_code"], errors="coerce")
df_clean
# Out:
#          horse_id  race_date  weather race_no       race_id  num_of_horses  \
# 0      2011106610 2023-10-07      0.0       9  202308020109             11
# 1      2011106610 2023-10-29      0.0       9  202308020909              9
# 2      2011106610 2023-11-11      1.0      12  202305050312              8
# 3      2011106610 2023-12-10      0.0       8  202309050408              8
# 12     2012100683 2023-10-01      1.0      12  202309040912             16
# ...           ...        ...      ...     ...           ...            ...
# 32056  2021110164 2024-04-14      0.0       5  202406030805             16
# 32057  2021110166 2024-01-28      0.0       5  202408020205             13
# 32058  2021110166 2024-02-24      0.0       5  202406020105             16
# 32059  2021110169 2024-01-14      0.0       5  202408010505             18
# 32060  2021110169 2024-02-03      0.0       5  202408020305             16
#
#       frame_no horse_no   odds popularity finish_position jockey_id weight  \
# 0            8       10  262.8         11              11     01200     58
# 1            2        2  222.4          9               9     01208     58
# 2            7        7  206.9          8               8     01188     57
# 3            1        1  211.8          8               8     01202     55
# 12           7       14   42.2         12               1     01208     55
# ...        ...      ...    ...        ...             ...       ...    ...
# 32056        2        4    1.3          1               1     01088     55
# 32057        6        9   19.0          7              11     05659     55
# 32058        1        2   36.7          8              11     05643     55
# 32059        2        3   71.5         11               5     01179     57
# 32060        7       14   86.4         11              12     01180     57
#
#        course_condition   time  margin final_3f prize_money  course_state  \
# 0                   0.0   95.8     1.8     34.4                         0
# 1                   0.0  110.2     2.3     34.9                         0
# 2                   0.0   96.1     1.6     34.7                         0
# 3                   0.0  151.9     3.9     36.4                         0
# 12                  2.0   83.9    -0.1     36.9     1,140.0             1
# ...                 ...    ...     ...      ...         ...           ...
# 32056               0.0   70.6    -0.7     36.3       780.0             1
# 32057               0.0  125.5     1.9     36.5                         0
# 32058               NaN  124.6     1.7     37.5                         0
# 32059               0.0   95.7     0.6     36.2        62.0             0
# 32060               0.0   96.1     1.7     37.9                         0
#
#        distance_length  passing_1st  passing_2nd  passing_3rd  passing_4th  \
# 0                 1600         10.0         10.0          NaN          NaN
# 1                 1800          7.0          7.0          NaN          NaN
# 2                 1600          6.0          6.0          NaN          NaN
# 3                 2400          8.0          8.0          8.0          7.0
# 12                1400          7.0          8.0          NaN          NaN
# ...                ...          ...          ...          ...          ...
# 32056             1200          1.0          1.0          NaN          NaN
# 32057             2000         12.0         13.0         13.0         12.0
# 32058             2000          8.0          7.0          9.0          7.0
# 32059             1600          1.0          1.0          NaN          NaN
# 32060             1600          2.0          2.0          NaN          NaN
#
#        pace_1st  pace_2nd  body_weight  body_diff  is_cash  actual_horses  \
# 0          36.0      33.5        478.0        4.0    False             11
# 1          36.5      33.4        478.0        0.0    False              9
# 2          35.9      34.9        494.0       16.0    False              8
# 3          38.2      33.7        480.0      -14.0    False              8
# 12         34.1      37.6        482.0       -4.0    False             16
# ...         ...       ...          ...        ...      ...            ...
# 32056      34.3      36.3        514.0       -2.0    False             16
# 32057      37.6      35.6        450.0        0.0    False             13
# 32058      36.6      36.6        442.0       -8.0    False             16
# 32059      34.7      35.6        482.0        0.0    False             18
# 32060      34.1      36.4        482.0        0.0    False             16
#
#        race_course_code
# 0                     8
# 1                     8
# 2                     5
# 3                     9
# 12                    9
# ...                 ...
# 32056                 6
# 32057                 8
# 32058                 6
# 32059                 8
# 32060                 8
#
# [28506 rows x 31 columns]

# %%
# # what: race_result_tableとhorse_result_tableで、キーとするrace_idとhorse_idに不一致がないか確認
# merged = df_race.merge(
#     df_clean,
#     on=["horse_id", "race_id"],
#     how="outer",
#     indicator=True
# )
# matched_count = (merged["_merge"] == "both").sum()
# print(f"Number of matched records: {matched_count}")
# unmatched_count = (merged["_merge"] != "both").sum()
# print(f"Number of unmatched records: {unmatched_count}") # 0にならなければ不整合なデータ有

# %%
# # what: 不整合データを確認（デバッグ用）
# unmatched_rows = merged[merged["_merge"] != "both"][["horse_id", "race_id"]] # 不整合データを一覧表示
# unmatched_rows
# df_race[(df_race["horse_id"] == "2015100744") & (df_race["race_id"] == "202410020411")] # 不整合データがrace_result_tableに存在するか確認
# df_clean[(df_clean["horse_id"] == "2015100744") & (df_clean["race_id"] == "202410020411")] # 不整合データがhorse_result_tableに存在するか確認

# %% [markdown]
# ## 前処理1. 対数化したオッズの取得

# %%
# オッズがstr型だったため数値に変更
df_clean["odds"] = pd.to_numeric(df_clean["odds"], errors="coerce")
# 対数化
df_clean['log_odds'] = np.log(df_clean['odds'])

# %%
# 馬ごと各レース時点での過去3, 5, 10試合のlog_oddsの平均をとる

# 「今見ている行より下側」の log_odds を参照するために shift(-1)
df_clean["log_odds_shift"] = df_clean.groupby("horse_id")["log_odds"].shift(+1)
# レース時点での過去3, 5, 10レースの平均を計算
df_clean["log_odds_avg3"] = (
    df_clean.groupby("horse_id")["log_odds_shift"]
      .rolling(3)
      .mean()
      .reset_index(level=0, drop=True)
)

df_clean["log_odds_avg5"] = (  
    df_clean.groupby("horse_id")["log_odds_shift"]
      .rolling(5)
      .mean()
      .reset_index(level=0, drop=True)
)

df_clean["log_odds_avg10"] = (
    df_clean.groupby("horse_id")["log_odds_shift"]
      .rolling(10)
      .mean()
      .reset_index(level=0, drop=True)
)
# 不要な列を削除
df_clean = df_clean.drop(columns=["log_odds_shift"])

# %% [markdown]
# ## 前処理2. 平均との差分を分布で割ったnレース平均(z-score)

# %%
df_clean['log_odds_zscore'] = (
    df_clean.groupby('race_id')['log_odds']
      .transform(lambda x: (x - x.mean()) / (x.std(ddof=0) + 1e-9))
)

# 「今見ている行より下側」の log_odds を参照するために shift(-1)
df_clean["log_odds_zscore_shift"] = df_clean.groupby("horse_id")["log_odds_zscore"].shift(+1)
# レース時点での過去3, 5, 10レースの平均を計算
df_clean["log_odds_zscore_avg3"] = (
    df_clean.groupby("horse_id")["log_odds_zscore_shift"]
      .rolling(3)
      .mean()
      .reset_index(level=0, drop=True)
)

df_clean["log_odds_zscore_avg5"] = (  
    df_clean.groupby("horse_id")["log_odds_zscore_shift"]
      .rolling(5)
      .mean()
      .reset_index(level=0, drop=True)
)

df_clean["log_odds_zscore_avg10"] = (
    df_clean.groupby("horse_id")["log_odds_zscore_shift"]
      .rolling(10)
      .mean()
      .reset_index(level=0, drop=True)
)
# 不要な列を削除
df_clean = df_clean.drop(columns=["log_odds_zscore_shift"])

# %%
# 追加した特徴量の確認
df_clean.head(15)
# Out:
#       horse_id  race_date  weather race_no       race_id  num_of_horses  \
# 0   2011106610 2023-10-07      0.0       9  202308020109             11
# 1   2011106610 2023-10-29      0.0       9  202308020909              9
# 2   2011106610 2023-11-11      1.0      12  202305050312              8
# 3   2011106610 2023-12-10      0.0       8  202309050408              8
# 12  2012100683 2023-10-01      1.0      12  202309040912             16
# 13  2012100683 2023-10-22      0.0      12  202308020712             14
# 14  2012100683 2023-12-17      0.0      12  202309050612             16
# 15  2012100683 2024-01-06      1.0       9  202408010109             12
# 16  2012100683 2024-02-17      0.0      10  202408020710             16
# 17  2012100683 2024-04-13      0.0      10  202409020710             15
# 18  2012103532 2023-11-11      0.0       8  202308030308             12
# 19  2012103532 2023-12-23      0.0      10  202306050710             12
# 20  2013101904 2023-11-11      0.0       8  202308030308             12
# 21  2013101904 2023-12-23      0.0      10  202306050710             12
# 22  2013101904 2024-02-24      0.0       8  202410020508             10
#
#    frame_no horse_no   odds popularity finish_position jockey_id weight  \
# 0         8       10  262.8         11              11     01200     58
# 1         2        2  222.4          9               9     01208     58
# 2         7        7  206.9          8               8     01188     57
# 3         1        1  211.8          8               8     01202     55
# 12        7       14   42.2         12               1     01208     55
# 13        3        4   24.9          8               5     01208     54
# 14        4        8  107.7         10               9     01208     58
# 15        6        7  238.0         12               8     01208     58
# 16        6       12  148.5         14               8     01208     54
# 17        8       15  276.8         13              12     01208     54
# 18        3        3   22.8          8               6     01066     60
# 19        8       11   19.2          7               7     01067     63
# 20        5        6   12.4          6               8     01123     60
# 21        7       10  142.9         10              12     01123     63
# 22        8        9   42.5          7               7     01123     60
#
#     course_condition   time  margin final_3f prize_money  course_state  \
# 0                0.0   95.8     1.8     34.4                         0
# 1                0.0  110.2     2.3     34.9                         0
# 2                0.0   96.1     1.6     34.7                         0
# 3                0.0  151.9     3.9     36.4                         0
# 12               2.0   83.9    -0.1     36.9     1,140.0             1
# 13               0.0   84.3     1.0     36.5       184.0             1
# 14               NaN   85.4     2.0     38.3                         1
# 15               0.0   84.6     1.1     37.1                         1
# 16               NaN   84.6     0.8     36.8                         1
# 17               0.0   85.0     1.3     36.6                         1
# 18               NaN  219.7     1.0     13.9                         2
# 19               0.0  282.8     4.9     13.8                         2
# 20               NaN  219.9     1.2     13.9                         2
# 21               0.0  285.9     8.0     13.9                         2
# 22               NaN  229.9     1.3     13.6                         2
#
#     distance_length  passing_1st  passing_2nd  passing_3rd  passing_4th  \
# 0              1600         10.0         10.0          NaN          NaN
# 1              1800          7.0          7.0          NaN          NaN
# 2              1600          6.0          6.0          NaN          NaN
# 3              2400          8.0          8.0          8.0          7.0
# 12             1400          7.0          8.0          NaN          NaN
# 13             1400          5.0          5.0          NaN          NaN
# 14             1400          7.0          8.0          NaN          NaN
# 15             1400         11.0         10.0          NaN          NaN
# 16             1400         11.0         11.0          NaN          NaN
# 17             1400         14.0         14.0          NaN          NaN
# 18             3170          6.0          9.0          7.0          7.0
# 19             4100         11.0         10.0         10.0          8.0
# 20             3170          8.0          5.0          5.0          5.0
# 21             4100          6.0          6.0          6.0          7.0
# 22             3390          9.0          7.0          7.0          8.0
#
#     pace_1st  pace_2nd  body_weight  body_diff  is_cash  actual_horses  \
# 0       36.0      33.5        478.0        4.0    False             11
# 1       36.5      33.4        478.0        0.0    False              9
# 2       35.9      34.9        494.0       16.0    False              8
# 3       38.2      33.7        480.0      -14.0    False              8
# 12      34.1      37.6        482.0       -4.0    False             16
# 13      35.3      36.0        480.0       -2.0    False             14
# 14      33.6      37.5        482.0        2.0    False             16
# 15      34.6      37.2        486.0        4.0    False             12
# 16      35.1      36.8        486.0        0.0    False             16
# 17      34.5      37.1        490.0        4.0    False             15
# 18     108.1       0.0        418.0        6.0    False             12
# 19     108.0       0.0        414.0       -4.0    False             12
# 20     108.1       0.0        426.0       -4.0    False             12
# 21     108.0       0.0        422.0       -4.0    False             12
# 22     106.0       0.0        424.0        2.0    False             10
#
#     race_course_code  log_odds  log_odds_avg3  log_odds_avg5  log_odds_avg10  \
# 0                  8  5.571393            NaN            NaN             NaN
# 1                  8  5.404478            NaN            NaN             NaN
# 2                  5  5.332236            NaN            NaN             NaN
# 3                  9  5.355642       5.436035            NaN             NaN
# 12                 9  3.742420            NaN            NaN             NaN
# 13                 8  3.214868            NaN            NaN             NaN
# 14                 9  4.679350            NaN            NaN             NaN
# 15                 8  5.472271       3.878879            NaN             NaN
# 16                 8  5.000585       4.455496            NaN             NaN
# 17                 9  5.623295       5.050735       4.421899             NaN
# 18                 8  3.126761            NaN            NaN             NaN
# 19                 6  2.954910            NaN            NaN             NaN
# 20                 8  2.517696            NaN            NaN             NaN
# 21                 6  4.962145            NaN            NaN             NaN
# 22                10  3.749504            NaN            NaN             NaN
#
#     log_odds_zscore  log_odds_zscore_avg3  log_odds_zscore_avg5  \
# 0          2.307862                   NaN                   NaN
# 1          2.093945                   NaN                   NaN
# 2          1.707527                   NaN                   NaN
# 3          1.704040              2.036444                   NaN
# 12         0.640503                   NaN                   NaN
# 13         0.076042                   NaN                   NaN
# 14         0.456573                   NaN                   NaN
# 15         1.922044              0.391039                   NaN
# 16         1.191760              0.818220                   NaN
# 17         1.281287              1.190126              0.857384
# 18         0.570410                   NaN                   NaN
# 19        -0.134553                   NaN                   NaN
# 20        -0.106980                   NaN                   NaN
# 21         1.211391                   NaN                   NaN
# 22         0.599830                   NaN                   NaN
#
#     log_odds_zscore_avg10
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN
# 18                    NaN
# 19                    NaN
# 20                    NaN
# 21                    NaN
# 22                    NaN

# %% [markdown]
# ## 前処理3. 人気(popularity)

# %%
# str型だったため数値に変更
df_clean["popularity"] = pd.to_numeric(df_clean["popularity"], errors="coerce")

# %% [markdown]
# ### popularity_inverse（人気の逆数）

# %%
df_clean["popularity_inverse"] = 1 / df_clean["popularity"]
df_clean["popularity_inverse_avg3"] = df_clean.groupby("horse_id")["popularity_inverse"].shift(1).rolling(3).mean()
df_clean["popularity_inverse_avg5"] = df_clean.groupby("horse_id")["popularity_inverse"].shift(1).rolling(5).mean()
df_clean["popularity_inverse_avg10"] = df_clean.groupby("horse_id")["popularity_inverse"].shift(1).rolling(10).mean()

# %% [markdown]
# ### popularity_bucket（人気のビン分割）

# %%
def popularity_bucket(pop):
    if pop <= 2:
        return 1      # 超上位人気
    elif pop <= 5:
        return 2      # 上位人気
    elif pop <= 9:
        return 3      # 中穴
    else:
        return 4      # 大穴

df_clean['popularity_bucket'] = df_clean['popularity'].apply(popularity_bucket)
df_clean["popularity_bucket_avg3"] = df_clean.groupby("horse_id")["popularity_bucket"].shift(1).rolling(3).mean()
df_clean["popularity_bucket_avg5"] = df_clean.groupby("horse_id")["popularity_bucket"].shift(1).rolling(5).mean()
df_clean["popularity_bucket_avg10"] = df_clean.groupby("horse_id")["popularity_bucket"].shift(1).rolling(10).mean()

# %% [markdown]
# ## 前処理4. 斤量（weight）

# %% [markdown]
# ### weight_minus_avg_in_race（レース内平均との差斤量）

# %%
df_clean['weight'] = pd.to_numeric(df_clean['weight'], errors='coerce')
df_clean['weight_minus_avg_in_race'] = (
    df_clean['weight'] - df_clean.groupby('race_id')['weight'].transform('mean')
)

# %% [markdown]
# ### weight_per_body_weight（馬体重に対する斤量比）

# %%
df_clean['weight_per_body_weight'] = df_clean['weight'] / df_clean['body_weight']

# %% [markdown]
# ## 前処理5. 最終順位（finish_position）

# %%
df_clean['finish_position'] = pd.to_numeric(df_clean['finish_position'], errors='coerce')

# %% [markdown]
# ### finish_position_inverse（最終順位の逆順）

# %%
df_clean["finish_position_inverse"] = 1 / df_clean["finish_position"]
df_clean["finish_position_inverse_avg3"] = df_clean.groupby("horse_id")["finish_position_inverse"].shift(1).rolling(3).mean()
df_clean["finish_position_inverse_avg5"] = df_clean.groupby("horse_id")["finish_position_inverse"].shift(1).rolling(5).mean()
df_clean["finish_position_inverse_avg10"] = df_clean.groupby("horse_id")["finish_position_inverse"].shift(1).rolling(10).mean()

# %% [markdown]
# ### expected_vs_actual_gap（期待順位と実順位の乖離）

# %%
df_clean['expected_vs_actual_gap'] = df_clean['popularity'] - df_clean['finish_position']
df_clean["expected_vs_actual_gap_avg3"] = df_clean.groupby("horse_id")["expected_vs_actual_gap"].shift(1).rolling(3).mean()
df_clean["expected_vs_actual_gap_avg5"] = df_clean.groupby("horse_id")["expected_vs_actual_gap"].shift(1).rolling(5).mean()
df_clean["expected_vs_actual_gap_avg10"] = df_clean.groupby("horse_id")["expected_vs_actual_gap"].shift(1).rolling(10).mean()

# %% [markdown]
# ## 前処理6. 走破タイム（time）

# %% [markdown]
# ### time_diff_from_winner（勝ち馬とのタイム差）

# %%
df_clean["time_diff_from_winner"] = df_clean["time"] - df_clean.groupby("race_id")["time"].transform("min")
df_clean["time_diff_from_winner_avg3"] = df_clean.groupby("horse_id")["time_diff_from_winner"].shift(1).rolling(3).mean()
df_clean["time_diff_from_winner_avg5"] = df_clean.groupby("horse_id")["time_diff_from_winner"].shift(1).rolling(5).mean()
df_clean["time_diff_from_winner_avg10"] = df_clean.groupby("horse_id")["time_diff_from_winner"].shift(1).rolling(10).mean()

# %% [markdown]
# ### time_zscore_in_race（レース内Zスコア）

# %%
df_clean["time_zscore_in_race"] = (df_clean["time"] - df_clean.groupby("race_id")["time"].transform("mean")) / df_clean.groupby("race_id")["time"].transform("std")
df_clean["time_zscore_in_race_avg3"] = df_clean.groupby("horse_id")["time_zscore_in_race"].shift(1).rolling(3).mean()
df_clean["time_zscore_in_race_avg5"] = df_clean.groupby("horse_id")["time_zscore_in_race"].shift(1).rolling(5).mean()
df_clean["time_zscore_in_race_avg10"] = df_clean.groupby("horse_id")["time_zscore_in_race"].shift(1).rolling(10).mean()

# %% [markdown]
# ## 前処理7. 着差（margin）

# %% [markdown]
# ### margin_to_winner（勝ち馬との差）

# %%
# df_clean["margin_to_winner"] = df_clean.groupby("race_id")["margin"].cumsum()
# df_clean["margin_to_winner_avg3"] = df_clean.groupby("horse_id")["margin_to_winner"].shift(1).rolling(3).mean()
# df_clean["margin_to_winner_avg5"] = df_clean.groupby("horse_id")["margin_to_winner"].shift(1).rolling(5).mean()
# df_clean["margin_to_winner_avg10"] = df_clean.groupby("horse_id")["margin_to_winner"].shift(1).rolling(10).mean()

# %% [markdown]
# ## 前処理8. 上がり3F（final_3f）

# %%
# str型だったため数値に変更
df_clean["final_3f"] = pd.to_numeric(df_clean["final_3f"], errors="coerce")

# %% [markdown]
# ### final_3f_rank（レース内順位）

# %%
df_clean["final_3f_rank"] = df_clean.groupby("race_id")["final_3f"].rank(ascending=True)
df_clean["final_3f_rank_avg3"] = df_clean.groupby("horse_id")["final_3f_rank"].shift(1).rolling(3).mean()
df_clean["final_3f_rank_avg5"] = df_clean.groupby("horse_id")["final_3f_rank"].shift(1).rolling(5).mean()
df_clean["final_3f_rank_avg10"] = df_clean.groupby("horse_id")["final_3f_rank"].shift(1).rolling(10).mean()

# %% [markdown]
# ### final_3f_diff_from_best（最速との差）

# %%
df_clean["final_3f_diff_from_best"] = df_clean["final_3f"] - df_clean.groupby("race_id")["final_3f"].transform("min")
df_clean["final_3f_diff_avg3"] = df_clean.groupby("horse_id")["final_3f_diff_from_best"].shift(1).rolling(3).mean()
df_clean["final_3f_diff_avg5"] = df_clean.groupby("horse_id")["final_3f_diff_from_best"].shift(1).rolling(5).mean()
df_clean["final_3f_diff_avg10"] = df_clean.groupby("horse_id")["final_3f_diff_from_best"].shift(1).rolling(10).mean()

# %% [markdown]
# ### final_3f_zscore

# %%
df_clean["final_3f_zscore"] = (df_clean["final_3f"] - df_clean.groupby("race_id")["final_3f"].transform("mean")) / df_clean.groupby("race_id")["final_3f"].transform("std")
df_clean["final_3f_zscore_avg3"] = df_clean.groupby("horse_id")["final_3f_zscore"].shift(1).rolling(3).mean()
df_clean["final_3f_zscore_avg5"] = df_clean.groupby("horse_id")["final_3f_zscore"].shift(1).rolling(5).mean()
df_clean["final_3f_zscore_avg10"] = df_clean.groupby("horse_id")["final_3f_zscore"].shift(1).rolling(10).mean()

# %% [markdown]
# ## 前処理9. 賞金(prize_money)

# %% [markdown]
# ### log_prize（賞金の対数変換）

# %%
# str型だったため数値に変更
df_clean["prize_money"] = pd.to_numeric(df_clean["prize_money"], errors="coerce")

# 対数変換（賞金の歪み対策）
df_clean['log_prize_money'] = np.log1p(df_clean['prize_money'])

# 直近N走平均
df_clean['log_prize_avg3'] = df_clean.groupby('horse_id')['log_prize_money'].shift(1).rolling(3).mean()
df_clean['log_prize_avg5'] = df_clean.groupby('horse_id')['log_prize_money'].shift(1).rolling(5).mean()
df_clean['log_prize_avg10'] = df_clean.groupby('horse_id')['log_prize_money'].shift(1).rolling(10).mean()

# %% [markdown]
# ## 前処理10. 通過順位（passing_1st ~ _4th）

# %% [markdown]
# ### passing_{n}_rel（相対位置）

# %%
df_clean["passing_1st"] = pd.to_numeric(df_clean["passing_1st"], errors="coerce")
df_clean["passing_2nd"] = pd.to_numeric(df_clean["passing_2nd"], errors="coerce")
df_clean["passing_3rd"] = pd.to_numeric(df_clean["passing_3rd"], errors="coerce")
df_clean["passing_4th"] = pd.to_numeric(df_clean["passing_4th"], errors="coerce")
passing_cols = ['passing_1st','passing_2nd','passing_3rd','passing_4th']

# 頭数で割って相対位置に変換
for c in passing_cols:
    df_clean[c + '_rel'] = (df_clean['num_of_horses'] - df_clean[c]) / df_clean['num_of_horses']
    # 直近N走平均（例：3走）
    df_clean[c + '_rel' + '_avg3'] = df_clean.groupby('horse_id')[c + '_rel'].shift(1).rolling(3).mean()
    df_clean[c + '_rel' + '_avg5'] = df_clean.groupby('horse_id')[c + '_rel'].shift(1).rolling(5).mean()
    df_clean[c + '_rel' + '_avg10'] = df_clean.groupby('horse_id')[c + '_rel'].shift(1).rolling(10).mean()

# %%
df_clean
# Out:
#          horse_id  race_date  weather race_no       race_id  num_of_horses  \
# 0      2011106610 2023-10-07      0.0       9  202308020109             11
# 1      2011106610 2023-10-29      0.0       9  202308020909              9
# 2      2011106610 2023-11-11      1.0      12  202305050312              8
# 3      2011106610 2023-12-10      0.0       8  202309050408              8
# 12     2012100683 2023-10-01      1.0      12  202309040912             16
# ...           ...        ...      ...     ...           ...            ...
# 32056  2021110164 2024-04-14      0.0       5  202406030805             16
# 32057  2021110166 2024-01-28      0.0       5  202408020205             13
# 32058  2021110166 2024-02-24      0.0       5  202406020105             16
# 32059  2021110169 2024-01-14      0.0       5  202408010505             18
# 32060  2021110169 2024-02-03      0.0       5  202408020305             16
#
#       frame_no horse_no   odds  popularity  finish_position jockey_id  weight  \
# 0            8       10  262.8        11.0             11.0     01200    58.0
# 1            2        2  222.4         9.0              9.0     01208    58.0
# 2            7        7  206.9         8.0              8.0     01188    57.0
# 3            1        1  211.8         8.0              8.0     01202    55.0
# 12           7       14   42.2        12.0              1.0     01208    55.0
# ...        ...      ...    ...         ...              ...       ...     ...
# 32056        2        4    1.3         1.0              1.0     01088    55.0
# 32057        6        9   19.0         7.0             11.0     05659    55.0
# 32058        1        2   36.7         8.0             11.0     05643    55.0
# 32059        2        3   71.5        11.0              5.0     01179    57.0
# 32060        7       14   86.4        11.0             12.0     01180    57.0
#
#        course_condition   time  margin  final_3f  prize_money  course_state  \
# 0                   0.0   95.8     1.8      34.4          NaN             0
# 1                   0.0  110.2     2.3      34.9          NaN             0
# 2                   0.0   96.1     1.6      34.7          NaN             0
# 3                   0.0  151.9     3.9      36.4          NaN             0
# 12                  2.0   83.9    -0.1      36.9          NaN             1
# ...                 ...    ...     ...       ...          ...           ...
# 32056               0.0   70.6    -0.7      36.3        780.0             1
# 32057               0.0  125.5     1.9      36.5          NaN             0
# 32058               NaN  124.6     1.7      37.5          NaN             0
# 32059               0.0   95.7     0.6      36.2         62.0             0
# 32060               0.0   96.1     1.7      37.9          NaN             0
#
#        distance_length  passing_1st  passing_2nd  passing_3rd  passing_4th  \
# 0                 1600         10.0         10.0          NaN          NaN
# 1                 1800          7.0          7.0          NaN          NaN
# 2                 1600          6.0          6.0          NaN          NaN
# 3                 2400          8.0          8.0          8.0          7.0
# 12                1400          7.0          8.0          NaN          NaN
# ...                ...          ...          ...          ...          ...
# 32056             1200          1.0          1.0          NaN          NaN
# 32057             2000         12.0         13.0         13.0         12.0
# 32058             2000          8.0          7.0          9.0          7.0
# 32059             1600          1.0          1.0          NaN          NaN
# 32060             1600          2.0          2.0          NaN          NaN
#
#        pace_1st  pace_2nd  body_weight  body_diff  is_cash  actual_horses  \
# 0          36.0      33.5        478.0        4.0    False             11
# 1          36.5      33.4        478.0        0.0    False              9
# 2          35.9      34.9        494.0       16.0    False              8
# 3          38.2      33.7        480.0      -14.0    False              8
# 12         34.1      37.6        482.0       -4.0    False             16
# ...         ...       ...          ...        ...      ...            ...
# 32056      34.3      36.3        514.0       -2.0    False             16
# 32057      37.6      35.6        450.0        0.0    False             13
# 32058      36.6      36.6        442.0       -8.0    False             16
# 32059      34.7      35.6        482.0        0.0    False             18
# 32060      34.1      36.4        482.0        0.0    False             16
#
#        race_course_code  log_odds  log_odds_avg3  log_odds_avg5  \
# 0                     8  5.571393            NaN            NaN
# 1                     8  5.404478            NaN            NaN
# 2                     5  5.332236            NaN            NaN
# 3                     9  5.355642       5.436035            NaN
# 12                    9  3.742420            NaN            NaN
# ...                 ...       ...            ...            ...
# 32056                 6  0.262364            NaN            NaN
# 32057                 8  2.944439            NaN            NaN
# 32058                 6  3.602777            NaN            NaN
# 32059                 8  4.269697            NaN            NaN
# 32060                 8  4.458988            NaN            NaN
#
#        log_odds_avg10  log_odds_zscore  log_odds_zscore_avg3  \
# 0                 NaN         2.307862                   NaN
# 1                 NaN         2.093945                   NaN
# 2                 NaN         1.707527                   NaN
# 3                 NaN         1.704040              2.036444
# 12                NaN         0.640503                   NaN
# ...               ...              ...                   ...
# 32056             NaN        -2.341287                   NaN
# 32057             NaN        -0.142097                   NaN
# 32058             NaN        -0.058410                   NaN
# 32059             NaN         0.404397                   NaN
# 32060             NaN         0.642358                   NaN
#
#        log_odds_zscore_avg5  log_odds_zscore_avg10  popularity_inverse  \
# 0                       NaN                    NaN            0.090909
# 1                       NaN                    NaN            0.111111
# 2                       NaN                    NaN            0.125000
# 3                       NaN                    NaN            0.125000
# 12                      NaN                    NaN            0.083333
# ...                     ...                    ...                 ...
# 32056                   NaN                    NaN            1.000000
# 32057                   NaN                    NaN            0.142857
# 32058                   NaN                    NaN            0.125000
# 32059                   NaN                    NaN            0.090909
# 32060                   NaN                    NaN            0.090909
#
#        popularity_inverse_avg3  popularity_inverse_avg5  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                     0.109007                      NaN
# 12                         NaN                      NaN
# ...                        ...                      ...
# 32056                      NaN                      NaN
# 32057                      NaN                      NaN
# 32058                      NaN                      NaN
# 32059                      NaN                      NaN
# 32060                      NaN                      NaN
#
#        popularity_inverse_avg10  popularity_bucket  popularity_bucket_avg3  \
# 0                           NaN                  4                     NaN
# 1                           NaN                  3                     NaN
# 2                           NaN                  3                     NaN
# 3                           NaN                  3                3.333333
# 12                          NaN                  4                     NaN
# ...                         ...                ...                     ...
# 32056                       NaN                  1                     NaN
# 32057                       NaN                  3                     NaN
# 32058                       NaN                  3                     NaN
# 32059                       NaN                  4                     NaN
# 32060                       NaN                  4                     NaN
#
#        popularity_bucket_avg5  popularity_bucket_avg10  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 12                        NaN                      NaN
# ...                       ...                      ...
# 32056                     NaN                      NaN
# 32057                     NaN                      NaN
# 32058                     NaN                      NaN
# 32059                     NaN                      NaN
# 32060                     NaN                      NaN
#
#        weight_minus_avg_in_race  weight_per_body_weight  \
# 0                      1.272727                0.121339
# 1                      1.333333                0.121339
# 2                      0.125000                0.115385
# 3                     -1.000000                0.114583
# 12                    -1.500000                0.114108
# ...                         ...                     ...
# 32056                 -0.750000                0.107004
# 32057                 -0.230769                0.122222
# 32058                 -0.500000                0.124434
# 32059                  1.555556                0.118257
# 32060                  0.937500                0.118257
#
#        finish_position_inverse  finish_position_inverse_avg3  \
# 0                     0.090909                           NaN
# 1                     0.111111                           NaN
# 2                     0.125000                           NaN
# 3                     0.125000                      0.109007
# 12                    1.000000                           NaN
# ...                        ...                           ...
# 32056                 1.000000                           NaN
# 32057                 0.090909                           NaN
# 32058                 0.090909                           NaN
# 32059                 0.200000                           NaN
# 32060                 0.083333                           NaN
#
#        finish_position_inverse_avg5  finish_position_inverse_avg10  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 12                              NaN                            NaN
# ...                             ...                            ...
# 32056                           NaN                            NaN
# 32057                           NaN                            NaN
# 32058                           NaN                            NaN
# 32059                           NaN                            NaN
# 32060                           NaN                            NaN
#
#        expected_vs_actual_gap  expected_vs_actual_gap_avg3  \
# 0                         0.0                          NaN
# 1                         0.0                          NaN
# 2                         0.0                          NaN
# 3                         0.0                          0.0
# 12                       11.0                          NaN
# ...                       ...                          ...
# 32056                     0.0                          NaN
# 32057                    -4.0                          NaN
# 32058                    -3.0                          NaN
# 32059                     6.0                          NaN
# 32060                    -1.0                          NaN
#
#        expected_vs_actual_gap_avg5  expected_vs_actual_gap_avg10  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 12                             NaN                           NaN
# ...                            ...                           ...
# 32056                          NaN                           NaN
# 32057                          NaN                           NaN
# 32058                          NaN                           NaN
# 32059                          NaN                           NaN
# 32060                          NaN                           NaN
#
#        time_diff_from_winner  time_diff_from_winner_avg3  \
# 0                        1.8                         NaN
# 1                        2.3                         NaN
# 2                        1.6                         NaN
# 3                        3.9                         1.9
# 12                       0.0                         NaN
# ...                      ...                         ...
# 32056                    0.0                         NaN
# 32057                    1.9                         NaN
# 32058                    1.7                         NaN
# 32059                    0.6                         NaN
# 32060                    1.7                         NaN
#
#        time_diff_from_winner_avg5  time_diff_from_winner_avg10  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 12                            NaN                          NaN
# ...                           ...                          ...
# 32056                         NaN                          NaN
# 32057                         NaN                          NaN
# 32058                         NaN                          NaN
# 32059                         NaN                          NaN
# 32060                         NaN                          NaN
#
#        time_zscore_in_race  time_zscore_in_race_avg3  \
# 0                 2.489991                       NaN
# 1                 2.261523                       NaN
# 2                 2.177701                       NaN
# 3                 2.354450                  2.309738
# 12               -1.399603                       NaN
# ...                    ...                       ...
# 32056            -2.414284                       NaN
# 32057             1.006716                       NaN
# 32058             0.247858                       NaN
# 32059            -0.860240                       NaN
# 32060             0.060829                       NaN
#
#        time_zscore_in_race_avg5  time_zscore_in_race_avg10  final_3f_rank  \
# 0                           NaN                        NaN           11.0
# 1                           NaN                        NaN            9.0
# 2                           NaN                        NaN            7.0
# 3                           NaN                        NaN            8.0
# 12                          NaN                        NaN            3.5
# ...                         ...                        ...            ...
# 32056                       NaN                        NaN            3.0
# 32057                       NaN                        NaN            9.0
# 32058                       NaN                        NaN           11.0
# 32059                       NaN                        NaN           12.5
# 32060                       NaN                        NaN           12.0
#
#        final_3f_rank_avg3  final_3f_rank_avg5  final_3f_rank_avg10  \
# 0                     NaN                 NaN                  NaN
# 1                     NaN                 NaN                  NaN
# 2                     NaN                 NaN                  NaN
# 3                     9.0                 NaN                  NaN
# 12                    NaN                 NaN                  NaN
# ...                   ...                 ...                  ...
# 32056                 NaN                 NaN                  NaN
# 32057                 NaN                 NaN                  NaN
# 32058                 NaN                 NaN                  NaN
# 32059                 NaN                 NaN                  NaN
# 32060                 NaN                 NaN                  NaN
#
#        final_3f_diff_from_best  final_3f_diff_avg3  final_3f_diff_avg5  \
# 0                          1.6                 NaN                 NaN
# 1                          1.9                 NaN                 NaN
# 2                          1.6                 NaN                 NaN
# 3                          3.3                 1.7                 NaN
# 12                         0.5                 NaN                 NaN
# ...                        ...                 ...                 ...
# 32056                      0.5                 NaN                 NaN
# 32057                      0.9                 NaN                 NaN
# 32058                      1.9                 NaN                 NaN
# 32059                      1.9                 NaN                 NaN
# 32060                      3.1                 NaN                 NaN
#
#        final_3f_diff_avg10  final_3f_zscore  final_3f_zscore_avg3  \
# 0                      NaN         2.058248                   NaN
# 1                      NaN         2.260777                   NaN
# 2                      NaN         1.232776                   NaN
# 3                      NaN         2.298688                1.8506
# 12                     NaN        -0.950100                   NaN
# ...                    ...              ...                   ...
# 32056                  NaN        -1.107421                   NaN
# 32057                  NaN         0.659268                   NaN
# 32058                  NaN         0.351825                   NaN
# 32059                  NaN         0.288941                   NaN
# 32060                  NaN         0.383685                   NaN
#
#        final_3f_zscore_avg5  final_3f_zscore_avg10  log_prize_money  \
# 0                       NaN                    NaN              NaN
# 1                       NaN                    NaN              NaN
# 2                       NaN                    NaN              NaN
# 3                       NaN                    NaN              NaN
# 12                      NaN                    NaN              NaN
# ...                     ...                    ...              ...
# 32056                   NaN                    NaN         6.660575
# 32057                   NaN                    NaN              NaN
# 32058                   NaN                    NaN              NaN
# 32059                   NaN                    NaN         4.143135
# 32060                   NaN                    NaN              NaN
#
#        log_prize_avg3  log_prize_avg5  log_prize_avg10  passing_1st_rel  \
# 0                 NaN             NaN              NaN         0.090909
# 1                 NaN             NaN              NaN         0.222222
# 2                 NaN             NaN              NaN         0.250000
# 3                 NaN             NaN              NaN         0.000000
# 12                NaN             NaN              NaN         0.562500
# ...               ...             ...              ...              ...
# 32056             NaN             NaN              NaN         0.937500
# 32057             NaN             NaN              NaN         0.076923
# 32058             NaN             NaN              NaN         0.500000
# 32059             NaN             NaN              NaN         0.944444
# 32060             NaN             NaN              NaN         0.875000
#
#        passing_1st_rel_avg3  passing_1st_rel_avg5  passing_1st_rel_avg10  \
# 0                       NaN                   NaN                    NaN
# 1                       NaN                   NaN                    NaN
# 2                       NaN                   NaN                    NaN
# 3                   0.18771                   NaN                    NaN
# 12                      NaN                   NaN                    NaN
# ...                     ...                   ...                    ...
# 32056                   NaN                   NaN                    NaN
# 32057                   NaN                   NaN                    NaN
# 32058                   NaN                   NaN                    NaN
# 32059                   NaN                   NaN                    NaN
# 32060                   NaN                   NaN                    NaN
#
#        passing_2nd_rel  passing_2nd_rel_avg3  passing_2nd_rel_avg5  \
# 0             0.090909                   NaN                   NaN
# 1             0.222222                   NaN                   NaN
# 2             0.250000                   NaN                   NaN
# 3             0.000000               0.18771                   NaN
# 12            0.500000                   NaN                   NaN
# ...                ...                   ...                   ...
# 32056         0.937500                   NaN                   NaN
# 32057         0.000000                   NaN                   NaN
# 32058         0.562500                   NaN                   NaN
# 32059         0.944444                   NaN                   NaN
# 32060         0.875000                   NaN                   NaN
#
#        passing_2nd_rel_avg10  passing_3rd_rel  passing_3rd_rel_avg3  \
# 0                        NaN              NaN                   NaN
# 1                        NaN              NaN                   NaN
# 2                        NaN              NaN                   NaN
# 3                        NaN           0.0000                   NaN
# 12                       NaN              NaN                   NaN
# ...                      ...              ...                   ...
# 32056                    NaN              NaN                   NaN
# 32057                    NaN           0.0000                   NaN
# 32058                    NaN           0.4375                   NaN
# 32059                    NaN              NaN                   NaN
# 32060                    NaN              NaN                   NaN
#
#        passing_3rd_rel_avg5  passing_3rd_rel_avg10  passing_4th_rel  \
# 0                       NaN                    NaN              NaN
# 1                       NaN                    NaN              NaN
# 2                       NaN                    NaN              NaN
# 3                       NaN                    NaN         0.125000
# 12                      NaN                    NaN              NaN
# ...                     ...                    ...              ...
# 32056                   NaN                    NaN              NaN
# 32057                   NaN                    NaN         0.076923
# 32058                   NaN                    NaN         0.562500
# 32059                   NaN                    NaN              NaN
# 32060                   NaN                    NaN              NaN
#
#        passing_4th_rel_avg3  passing_4th_rel_avg5  passing_4th_rel_avg10
# 0                       NaN                   NaN                    NaN
# 1                       NaN                   NaN                    NaN
# 2                       NaN                   NaN                    NaN
# 3                       NaN                   NaN                    NaN
# 12                      NaN                   NaN                    NaN
# ...                     ...                   ...                    ...
# 32056                   NaN                   NaN                    NaN
# 32057                   NaN                   NaN                    NaN
# 32058                   NaN                   NaN                    NaN
# 32059                   NaN                   NaN                    NaN
# 32060                   NaN                   NaN                    NaN
#
# [28506 rows x 97 columns]

# %% [markdown]
# ## テーブルのマージ（horse_result_table to race_result_table）

# %%
# log_odds_avgの各カラムの欠損値をチェック
nan_counts = {
    'log_odds_avg3': df_clean['log_odds_avg3'].isna().sum(),
    'log_odds_avg5': df_clean['log_odds_avg5'].isna().sum(),
    'log_odds_avg10': df_clean['log_odds_avg10'].isna().sum(),
}

total_rows = len(df_clean)
print(f"全行数: {total_rows}")
print("\n各カラムの欠損値数:")
for col, count in nan_counts.items():
    percentage = (count / total_rows) * 100
    print(f"{col}: {count} ({percentage:.2f}%)")
# Out:
# 全行数: 28506
#
# 各カラムの欠損値数:
# log_odds_avg3: 21585 (75.72%)
# log_odds_avg5: 27146 (95.23%)
# log_odds_avg10: 28506 (100.00%)

# %%
# 抽出する特徴量の指定
with open(r'C:\Users\yasak\Desktop\mykeibaAI\code\features.yaml', 'r', encoding='utf-8') as f:
    data = yaml.safe_load(f)
    features = data['features']
df_merged_race = df_race.merge(df_clean[features], on=["horse_id", "race_id"], how="left")

# %%
# マージしたテーブルの確認
df_merged_race
# Out:
#            date       race_id  is_win rank    horse_id  weight_carried  \
# 0      20231001  202309040910       1    1  2019105746            58.0
# 1      20231001  202309040910       0    2  2019102983            58.0
# 2      20231001  202309040910       0    3  2018104746            58.0
# 3      20231001  202309040910       0    4  2019100108            58.0
# 4      20231001  202309040910       0    5  2019103518            58.0
# ...         ...           ...     ...  ...         ...             ...
# 28501  20240428  202408030411       0   14  2018104609            58.0
# 28502  20240428  202408030411       0   15  2020103650            58.0
# 28503  20240428  202408030411       0   16  2016104946            58.0
# 28504  20240428  202408030411       0   中止  2019100630            58.0
# 28505  20240428  202408030411       0   取消  2016104851            58.0
#
#       jockey_id  popularity   odds  last3f trainer_id  body_weight  sex  age  \
# 0         05203         5.0    7.2    35.9      01127        494.0    0  4.0
# 1         01093         8.0   22.2    36.3      01069        494.0    0  4.0
# 2         01174         4.0    7.0    36.8      00429        494.0    2  5.0
# 3         01157        11.0   33.9    37.1      01039        494.0    0  4.0
# 4         01128        10.0   30.1    36.8      00425        532.0    0  4.0
# ...         ...         ...    ...     ...        ...          ...  ...  ...
# 28501     01157         8.0   39.8    39.4      01070        482.0    2  6.0
# 28502     05386         2.0    2.8    40.5      01103        464.0    0  4.0
# 28503     05212         7.0   34.6    40.3      01071        462.0    0  8.0
# 28504     01115        15.0  199.1     NaN      01058        486.0    0  5.0
# 28505     01180         NaN    NaN     NaN      01151          NaN    2  8.0
#
#        time_sec  body_diff  weight  weather  num_of_horses  course_condition  \
# 0         111.3       -4.0    58.0      1.0             12               2.0
# 1         111.4       -6.0    58.0      1.0             12               2.0
# 2         111.5        0.0    58.0      1.0             12               2.0
# 3         111.6        0.0    58.0      1.0             12               2.0
# 4         111.6        8.0    58.0      1.0             12               2.0
# ...         ...        ...     ...      ...            ...               ...
# 28501     199.0       -4.0    58.0      0.0             17               0.0
# 28502     199.8       -8.0    58.0      0.0             17               0.0
# 28503     200.0        8.0    58.0      0.0             17               0.0
# 28504       NaN        2.0    58.0      0.0             17               0.0
# 28505       NaN        NaN    58.0      0.0             17               0.0
#
#        course_state  distance_length  race_course_code  log_odds_avg3  \
# 0                 1             1800                 9            NaN
# 1                 1             1800                 9            NaN
# 2                 1             1800                 9            NaN
# 3                 1             1800                 9            NaN
# 4                 1             1800                 9            NaN
# ...             ...              ...               ...            ...
# 28501             0             3200                 8       1.886842
# 28502             0             3200                 8            NaN
# 28503             0             3200                 8            NaN
# 28504             0             3200                 8       1.339682
# 28505             0             3200                 8            NaN
#
#        log_odds_avg5  log_odds_avg10  log_odds_zscore_avg3  \
# 0                NaN             NaN                   NaN
# 1                NaN             NaN                   NaN
# 2                NaN             NaN                   NaN
# 3                NaN             NaN                   NaN
# 4                NaN             NaN                   NaN
# ...              ...             ...                   ...
# 28501            NaN             NaN             -0.997703
# 28502            NaN             NaN                   NaN
# 28503            NaN             NaN                   NaN
# 28504            NaN             NaN             -1.240625
# 28505            NaN             NaN                   NaN
#
#        log_odds_zscore_avg5  log_odds_zscore_avg10  popularity_inverse_avg3  \
# 0                       NaN                    NaN                      NaN
# 1                       NaN                    NaN                      NaN
# 2                       NaN                    NaN                      NaN
# 3                       NaN                    NaN                      NaN
# 4                       NaN                    NaN                      NaN
# ...                     ...                    ...                      ...
# 28501                   NaN                    NaN                 0.388889
# 28502                   NaN                    NaN                      NaN
# 28503                   NaN                    NaN                      NaN
# 28504                   NaN                    NaN                 0.566667
# 28505                   NaN                    NaN                      NaN
#
#        popularity_inverse_avg5  popularity_inverse_avg10  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 28501                      NaN                       NaN
# 28502                      NaN                       NaN
# 28503                      NaN                       NaN
# 28504                      NaN                       NaN
# 28505                      NaN                       NaN
#
#        popularity_bucket_avg3  popularity_bucket_avg5  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# ...                       ...                     ...
# 28501                1.666667                     NaN
# 28502                     NaN                     NaN
# 28503                     NaN                     NaN
# 28504                1.333333                     NaN
# 28505                     NaN                     NaN
#
#        popularity_bucket_avg10  weight_minus_avg_in_race  \
# 0                          NaN                  0.000000
# 1                          NaN                  0.000000
# 2                          NaN                  0.000000
# 3                          NaN                  0.000000
# 4                          NaN                  0.000000
# ...                        ...                       ...
# 28501                      NaN                  0.333333
# 28502                      NaN                  0.333333
# 28503                      NaN                  0.333333
# 28504                      NaN                  0.333333
# 28505                      NaN                  0.333333
#
#        weight_per_body_weight  finish_position_inverse_avg3  \
# 0                    0.117409                           NaN
# 1                    0.117409                           NaN
# 2                    0.117409                           NaN
# 3                    0.117409                           NaN
# 4                    0.109023                           NaN
# ...                       ...                           ...
# 28501                0.120332                      0.777778
# 28502                0.125000                           NaN
# 28503                0.125541                           NaN
# 28504                0.119342                      0.314815
# 28505                     NaN                           NaN
#
#        finish_position_inverse_avg5  finish_position_inverse_avg10  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
# ...                             ...                            ...
# 28501                           NaN                            NaN
# 28502                           NaN                            NaN
# 28503                           NaN                            NaN
# 28504                           NaN                            NaN
# 28505                           NaN                            NaN
#
#        expected_vs_actual_gap_avg3  expected_vs_actual_gap_avg5  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 28501                          1.0                          NaN
# 28502                          NaN                          NaN
# 28503                          NaN                          NaN
# 28504                         -2.0                          NaN
# 28505                          NaN                          NaN
#
#        expected_vs_actual_gap_avg10  time_diff_from_winner_avg3  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
# ...                             ...                         ...
# 28501                           NaN                    0.066667
# 28502                           NaN                         NaN
# 28503                           NaN                         NaN
# 28504                           NaN                    0.500000
# 28505                           NaN                         NaN
#
#        time_diff_from_winner_avg5  time_diff_from_winner_avg10  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 28501                         NaN                          NaN
# 28502                         NaN                          NaN
# 28503                         NaN                          NaN
# 28504                         NaN                          NaN
# 28505                         NaN                          NaN
#
#        time_zscore_in_race_avg3  time_zscore_in_race_avg5  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 28501                 -1.055535                       NaN
# 28502                       NaN                       NaN
# 28503                       NaN                       NaN
# 28504                 -0.675028                       NaN
# 28505                       NaN                       NaN
#
#        time_zscore_in_race_avg10  final_3f_rank_avg3  final_3f_rank_avg5  \
# 0                            NaN                 NaN                 NaN
# 1                            NaN                 NaN                 NaN
# 2                            NaN                 NaN                 NaN
# 3                            NaN                 NaN                 NaN
# 4                            NaN                 NaN                 NaN
# ...                          ...                 ...                 ...
# 28501                        NaN            5.833333                 NaN
# 28502                        NaN                 NaN                 NaN
# 28503                        NaN                 NaN                 NaN
# 28504                        NaN            3.666667                 NaN
# 28505                        NaN                 NaN                 NaN
#
#        final_3f_rank_avg10  final_3f_diff_avg3  final_3f_diff_avg5  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 28501                  NaN            0.633333                 NaN
# 28502                  NaN                 NaN                 NaN
# 28503                  NaN                 NaN                 NaN
# 28504                  NaN            0.433333                 NaN
# 28505                  NaN                 NaN                 NaN
#
#        final_3f_diff_avg10  final_3f_zscore_avg3  final_3f_zscore_avg5  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 28501                  NaN             -0.611317                   NaN
# 28502                  NaN                   NaN                   NaN
# 28503                  NaN                   NaN                   NaN
# 28504                  NaN             -0.750518                   NaN
# 28505                  NaN                   NaN                   NaN
#
#        final_3f_zscore_avg10  log_prize_avg3  log_prize_avg5  log_prize_avg10  \
# 0                        NaN             NaN             NaN              NaN
# 1                        NaN             NaN             NaN              NaN
# 2                        NaN             NaN             NaN              NaN
# 3                        NaN             NaN             NaN              NaN
# 4                        NaN             NaN             NaN              NaN
# ...                      ...             ...             ...              ...
# 28501                    NaN             NaN             NaN              NaN
# 28502                    NaN             NaN             NaN              NaN
# 28503                    NaN             NaN             NaN              NaN
# 28504                    NaN             NaN             NaN              NaN
# 28505                    NaN             NaN             NaN              NaN
#
#        passing_1st_rel_avg3  passing_1st_rel_avg5  passing_1st_rel_avg10  \
# 0                       NaN                   NaN                    NaN
# 1                       NaN                   NaN                    NaN
# 2                       NaN                   NaN                    NaN
# 3                       NaN                   NaN                    NaN
# 4                       NaN                   NaN                    NaN
# ...                     ...                   ...                    ...
# 28501              0.611111                   NaN                    NaN
# 28502                   NaN                   NaN                    NaN
# 28503                   NaN                   NaN                    NaN
# 28504              0.516178                   NaN                    NaN
# 28505                   NaN                   NaN                    NaN
#
#        passing_2nd_rel_avg3  passing_2nd_rel_avg5  passing_2nd_rel_avg10  \
# 0                       NaN                   NaN                    NaN
# 1                       NaN                   NaN                    NaN
# 2                       NaN                   NaN                    NaN
# 3                       NaN                   NaN                    NaN
# 4                       NaN                   NaN                    NaN
# ...                     ...                   ...                    ...
# 28501              0.601852                   NaN                    NaN
# 28502                   NaN                   NaN                    NaN
# 28503                   NaN                   NaN                    NaN
# 28504              0.490537                   NaN                    NaN
# 28505                   NaN                   NaN                    NaN
#
#        passing_3rd_rel_avg3  passing_3rd_rel_avg5  passing_3rd_rel_avg10  \
# 0                       NaN                   NaN                    NaN
# 1                       NaN                   NaN                    NaN
# 2                       NaN                   NaN                    NaN
# 3                       NaN                   NaN                    NaN
# 4                       NaN                   NaN                    NaN
# ...                     ...                   ...                    ...
# 28501              0.601852                   NaN                    NaN
# 28502                   NaN                   NaN                    NaN
# 28503                   NaN                   NaN                    NaN
# 28504              0.462759                   NaN                    NaN
# 28505                   NaN                   NaN                    NaN
#
#        passing_4th_rel_avg3  passing_4th_rel_avg5  passing_4th_rel_avg10
# 0                       NaN                   NaN                    NaN
# 1                       NaN                   NaN                    NaN
# 2                       NaN                   NaN                    NaN
# 3                       NaN                   NaN                    NaN
# 4                       NaN                   NaN                    NaN
# ...                     ...                   ...                    ...
# 28501              0.583333                   NaN                    NaN
# 28502                   NaN                   NaN                    NaN
# 28503                   NaN                   NaN                    NaN
# 28504              0.518315                   NaN                    NaN
# 28505                   NaN                   NaN                    NaN
#
# [28506 rows x 73 columns]

# %%
# マージしたテーブルに問題がなければpickleで保存
pd.to_pickle(df_merged_race, "C:\\Users\\yasak\\Desktop\\mykeibaAI\\data\\merged_table_260124.pkl")

# %%
# what: race_id_list.csvのファイル名に日付を記載しておく関数
# for:  どの期間のrace_idを取得したか一目でわかるようにするため
# in:   ファイルに書かれているキーワード
# out:  更新したファイルの名前

# %%
# what: race_id_list.csvのファイル名に日付を記載しておく関数
# for:  どの期間のrace_idを取得したか一目でわかるようにするため
